# %% [markdown]
# <a href="https://colab.research.google.com/github/LeonardoSanBenitez/Unlearn-Saliency/blob/master/Classification/01train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import files, drive

drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/LeonardoSanBenitez/Unlearn-Saliency.git
# Out:
# Cloning into 'Unlearn-Saliency'...
# remote: Enumerating objects: 591, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 591 (delta 74), reused 49 (delta 45), pack-reused 497 (from 1)
# Receiving objects: 100% (591/591), 8.11 MiB | 12.28 MiB/s, done.
# Resolving deltas: 100% (324/324), done.

# %%
# %cd Unlearn-Saliency/Classification
# Out:
# /content/Unlearn-Saliency/Classification

# %%
# !pip install -r requirements.txt

# %%
# %cd Unlearn-Saliency/Classification
# Out:
# /content/Unlearn-Saliency/Classification

# %%
# !pwd
# Out:
# /content/Unlearn-Saliency/Classification

# %%
# %time
# !python main_train.py --arch resnet18 --dataset cifar10 --lr 0.1 --epochs 182 --save_dir "assets/train"
# Out:
# setup random seed = 2
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Data augmentation = randomcrop(32,4) + randomhorizontalflip
# Files already downloaded and verified
# Files already downloaded and verified
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Data augmentation = randomcrop(32,4) + randomhorizontalflip
# Files already downloaded and verified
# Files already downloaded and verified
# setup random seed = 1
# The normalize layer is contained in the network
# setup random seed = 1
# number of train dataset 45000
# number of val dataset 5000
# Epoch #0, Learning rate: 0.1
# Epoch: [0][49/176]	Loss 1.8248 (2.2816)	Accuracy 30.078 (21.750)	Time 14.44
# Epoch: [0][99/176]	Loss 1.6694 (2.0103)	Accuracy 38.672 (27.695)	Time 13.16
# ...

# %%
assert os.path.exists("/content/Unlearn-Saliency/Classification/assets/train")

# !cp -r /content/Unlearn-Saliency/Classification/assets/train /content/gdrive/MyDrive/temp/unlearning/train/resnet

# %%
# Zip and download directly
#!zip -r /content/Unlearn-Saliency/Classification/assets/train.zip  /content/Unlearn-Saliency/Classification/assets/train
#files.download('/content/Unlearn-Saliency/Classification/assets/train.zip')

# %%
# !ls -lah assets/train/
# Out:
# total 171M
# drwxr-xr-x 2 root root 4.0K Dec 12 01:28 .
# drwxr-xr-x 4 root root 4.0K Dec 12 01:23 ..
# -rw-r--r-- 1 root root  86M Dec 12 04:06 0checkpoint.pth.tar
# -rw-r--r-- 1 root root  86M Dec 12 04:05 0model_SA_best.pth.tar
# -rw-r--r-- 1 root root  28K Dec 12 04:06 0net_train.png

# %%
# !python generate_mask.py --save_dir "assets/mask" --model_path "assets/train/0model_SA_best.pth.tar" --num_indexes_to_replace 100 --unlearn_epochs 1
# Out:
# setup random seed = 2
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Data augmentation = randomcrop(32,4) + randomhorizontalflip
# Files already downloaded and verified
# Files already downloaded and verified
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Data augmentation = randomcrop(32,4) + randomhorizontalflip
# Files already downloaded and verified
# Files already downloaded and verified
# Replacing indexes [25275 12561 24707 25066 33429 44157 40878 23566 25887 37512 13985 17087
#   4578  2741 17535 35513 32653 18505 23223 14479 41141 33469 22852 39997
#   8097 43099 10276   835 41465 35613 38617 21112  8078 31253 13296 15984
#  16816  6975  7638  2639 25521   391 31814 33933  7174 43075 29001 41116
# ...

# %%
# Out:
# total 853M
# drwxr-xr-x 2 root root 4.0K Dec 12 01:27 .
# drwxr-xr-x 4 root root 4.0K Dec 12 01:23 ..
# -rw-r--r-- 1 root root  86M Dec 12 04:06 with_0.1.pt
# -rw-r--r-- 1 root root  86M Dec 12 04:06 with_0.2.pt
# -rw-r--r-- 1 root root  86M Dec 12 04:06 with_0.3.pt
# -rw-r--r-- 1 root root  86M Dec 12 04:06 with_0.4.pt
# -rw-r--r-- 1 root root  86M Dec 12 04:06 with_0.5.pt
# -rw-r--r-- 1 root root  86M Dec 12 04:06 with_0.6.pt
# -rw-r--r-- 1 root root  86M Dec 12 04:06 with_0.7.pt
# -rw-r--r-- 1 root root  86M Dec 12 04:06 with_0.8.pt
# -rw-r--r-- 1 root root  86M Dec 12 04:06 with_0.9.pt
# -rw-r--r-- 1 root root  86M Dec 12 04:06 with_1.0.pt
